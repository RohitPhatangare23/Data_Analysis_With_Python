# %%
import matplotlib.pyplot as plt
import numpy as np
t=np.array([1,2,3,4])
plt.plot(t**2,t,color="r",label="square")   
plt.plot(t**3,t,color="b",label="cube")  
plt.plot(t,t**2,color="k",label="fourpow") 
plt.plot(t,t**3,color="g",label="fivepow") 

plt.grid()

plt.legend(title="MyInfo",title_fontsize=20)  


plt.title("Simple Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t=np.array([1,2,3,4])
plt.plot(t**2,t,color="r",label="square")   
plt.plot(t**3,t,color="b",label="cube")  
plt.plot(t,t**2,color="k",label="fourpow") 
plt.plot(t,t**3,color="g",label="fivepow") 

plt.grid()

plt.legend(title="myinfo",borderpad=1.9)  


plt.title("Simple Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t=np.array([1,2,3,4])
plt.plot(t**2,t,color="r",label="square")   
plt.plot(t**3,t,color="b",label="cube")  
plt.plot(t,t**2,color="k",label="fourpow") 
plt.plot(t,t**3,color="g",label="fivepow") 

plt.grid()

plt.legend(title="myinfo",labelspacing=3)  


plt.title("Simple Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
