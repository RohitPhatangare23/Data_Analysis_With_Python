# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[5,6,7,8])
plt.title("Simple Graph")
plt.xlabel("X-axis",{"size":23,"color":"r"},labelpad=-20,color="k")
plt.ylabel("Y-axis",{"size":30,"color":"g"})
plt.show()
