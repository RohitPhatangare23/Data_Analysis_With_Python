# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[5,6,7,8])
plt.title("First Plot",{"size":20,"color":"r"},loc="left",pad=50)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[5,6,7,8])
plt.title("First Plot",{"size":20,"color":"r"},color="g",size=90)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[5,6,7,8])
plt.title("First Plot",{"size":20,"color":"r"})
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show(block=False)   # it not block the executiion of the code
print("rohit")
# Out:
# rohit
