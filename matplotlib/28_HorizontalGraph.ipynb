# %%
import matplotlib.pyplot as plt
import numpy as np


y=["science","commerce","arts"]
h=[200,300,500]
# w=[0.5,0.3,0.9]   #width
# b=[100,200,300]   #bottom
c=["r","yellow","b"]
plt.barh(y,h,0.5,color=c,left=[20,40,90])





plt.title("Courses")
plt.xlabel("student enrooled")
plt.ylabel("student enrolld for diff courses")
plt.show()
