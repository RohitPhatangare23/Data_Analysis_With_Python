# %%
import matplotlib.pyplot as plt
import numpy as np


x=["USA","india","saouth africa","america","myanmar"]

gold=[20,10,6,24,30]
silver=[100,50,30,120,180]
bronze=[200,100,60,240,300]

b_bronze=list(np.add(gold,silver))
print(b_bronze)

plt.bar(x,gold,0.4,label="goald")
plt.bar(x,silver,0.4,bottom=gold,label="silver")
plt.bar(x,bronze,0.4,bottom=silvar,label="bronze")

plt.legend()

plt.title("coutrie")
plt.xlabel("medals")
plt.ylabel("medals vs country")
plt.show()
# Out:
# [120, 60, 36, 144, 210]

# %%
import matplotlib.pyplot as plt
import numpy as np

w=0.3
x=["USA","india","saouth africa","america","myanmar"]

boys=[20,10,6,24,30]
girls=[100,50,30,120,180]

b=[1,2,3,4,5]
g=[2,4,3,4,8]


plt.bar(x,boys,0.4,label="boy",yerr=b)
plt.bar(x,girls,0.4,bottom=boys,label="girl",yerr=g)

plt.legend()

plt.title("courses")
plt.xlabel("student")
plt.ylabel("courses vs student")
plt.show()
